# %% [markdown]
# # Flow-based Generative Models Demo
#
# This notebook demonstrates how to use the flow-based generative models implementation.
#
# ## Overview
#
# Flow-based models use invertible transformations to model complex distributions. They provide:
# - Exact likelihood estimation
# - Efficient sampling
# - Invertible transformations
#
# We'll demonstrate RealNVP and Glow architectures.
